# %%
from BTC_PaperWallet_Generator.KeyManager import KeyManager

# %% [markdown]
# ## Generate a New Key

# %%
mykey = KeyManager(new_key=True)

print(f'YOUR BITCOIN ADDRESS : {mykey.public_address}')
# Out:
# YOUR BITCOIN ADDRESS : 1DKhFHFexh4waXfzvzHuA8vX2gD6pRNEWm

# %% [markdown]
# ## Manage a Exisiting Key

# %%
ckey = KeyManager(new_key=False, import_key='L1osqYVtFveA4V1qwXgXZdEzDD4QrUFHyBEQNGN7abmmmRaxxyL6')
print(ckey.public_address)
dkey = KeyManager(False, '6PYQ6M1rrXCfgrEaFDbkEyujT9c6fwz6w3eaE9dg9wP9xq7VRwAbvayk2D', 'PASSWORD')
print(dkey.public_address)
# Out:
# 142bjwxKSthbz4KD3Duou7qzqLg6BQbn1T
# 19ASsVC58osrRY8d32iA5wPuoY2JTVHqRF

# %% [markdown]
# ## Generate a New Key with your Password

# %%
mykeyp = KeyManager(True, None, passwd='PASSWORD')
print(f'YOUR BITCOIN ADDRESS : {mykeyp.public_address}')
# Out:
# YOUR BITCOIN ADDRESS : 13Fj8w9nV9TtreUbyJEpPYADa3D3BDSVp2

# %% [markdown]
# ## Get QR Codes

# %%
mykeyp.get_encrypted_private_key_QR()
mykeyp.get_public_address_QR()
# Out:
# [WARNING] 비밀키를 직접 다룰 때는 보안에 유의하십시오.
# YOU MUST KNOW THAT IT IS DANGEROUS TO HANDLE THE PRV KEY
# [WARNING] 비밀키를 직접 다룰 때는 보안에 유의하십시오.
# YOU MUST KNOW THAT IT IS DANGEROUS TO HANDLE THE PRV KEY

# %% [markdown]
# # Advanced Features
# ---

# %% [markdown]
# ## Get your Encrypted Key

# %%
print(f'Your Encrypted Private Key : {mykeyp.encrypted_private_key}')
# Out:
# Your Encrypted Private Key : 6PYLBjAb967D18f7kThQUCK1AA7ppWei4Ex3eEwRdo9cUn4u8JxUh2Edv1

# %% [markdown]
# ## If you want to get your private key

# %%
print(mykey.private_key)
# Out:
# [WARNING] 비밀키를 직접 다룰 때는 보안에 유의하십시오.
# YOU MUST KNOW THAT IT IS DANGEROUS TO HANDLE THE PRV KEY
# Kyv5DDkLkEb5Fz5oAbz8nqP2YLpXZ5nQbM7XKJfVc4F7W1CmyJWX

# %% [markdown]
# ## Validity Check

# %%
print(mykeyp.public_address == KeyManager(False, mykeyp.private_key).public_address)
# Out:
# [WARNING] 비밀키를 직접 다룰 때는 보안에 유의하십시오.
# YOU MUST KNOW THAT IT IS DANGEROUS TO HANDLE THE PRV KEY
# False
